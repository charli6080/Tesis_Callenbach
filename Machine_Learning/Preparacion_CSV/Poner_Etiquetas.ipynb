# %% [markdown]
# # Colocación de etiquetas

# %% [markdown]
# # T344

# %% [markdown]
# ### 20-11-2025_T344_T7_date_OK

# %%
import pandas as pd

# Cargar archivo
ruta_archivo = 'Archivos_CSV_sin_etiquetas_dateOK/20-11-2025_T344_T7_date_OK.csv'
data = pd.read_csv(ruta_archivo)
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])

# Definir intervalos y actividades
actividades = {
    (pd.Timestamp('2025-11-16 13:10:09.167'),pd.Timestamp('2025-11-16 13:11:36.349')): 'Quieta', 
    (pd.Timestamp('2025-11-17 10:04:01.784'),pd.Timestamp('2025-11-17 10:23:06.345')): 'Quieta',    
    (pd.Timestamp('2025-11-17 10:24:16.164'),pd.Timestamp('2025-11-17 10:51:35.022')): 'Quieta',
    (pd.Timestamp('2025-11-17 11:10:28.854'),pd.Timestamp('2025-11-17 11:15:09.424')): 'Caminando',
    (pd.Timestamp('2025-11-17 11:15:09.494'),pd.Timestamp('2025-11-17 11:15:39.660')): 'Quieta',
    (pd.Timestamp('2025-11-17 11:15:39.729'),pd.Timestamp('2025-11-17 11:18:28.628')): 'Caminando',
    (pd.Timestamp('2025-11-18 10:08:05.422'),pd.Timestamp('2025-11-18 10:29:36.489')): 'Quieta', 
    (pd.Timestamp('2025-11-18 10:32:19.504'),pd.Timestamp('2025-11-18 10:35:53.442')): 'Caminando',   
    (pd.Timestamp('2025-11-18 10:36:30.528'),pd.Timestamp('2025-11-18 10:37:49.683')): 'Caminando',
    (pd.Timestamp('2025-11-18 10:39:57.964'),pd.Timestamp('2025-11-18 10:40:54.977')): 'Caminando',
    (pd.Timestamp('2025-11-18 10:53:05.290'),pd.Timestamp('2025-11-18 10:53:36.913')): 'Caminando',
    (pd.Timestamp('2025-11-18 10:53:36.982'),pd.Timestamp('2025-11-18 10:54:07.422')): 'Quieta',
    (pd.Timestamp('2025-11-18 10:54:08.252'),pd.Timestamp('2025-11-18 10:55:26.785')): 'Caminando', 
    (pd.Timestamp('2025-11-18 10:55:26.855'),pd.Timestamp('2025-11-18 10:55:58.060')): 'Quieta',    
    (pd.Timestamp('2025-11-18 10:59:00.102'),pd.Timestamp('2025-11-18 11:00:55.373')): 'Caminando',
    (pd.Timestamp('2025-11-18 12:06:48.460'),pd.Timestamp('2025-11-18 12:10:31.531')): 'Caminando'
}

# Función para asignar actividad
def asignar_actividad(row):
    tiempo_actual = row['dateTime_UTC']
    for (inicio, fin), actividad in actividades.items():
        if inicio <= tiempo_actual <= fin:
            return actividad
    return None  # Si no cae en ningún intervalo

# Crear columna de actividades
data['Actividades'] = data.apply(asignar_actividad, axis=1)

# Eliminar filas sin etiqueta
data_filtrado = data.dropna(subset=['Actividades'])

# Guardar archivo filtrado
salida = 'Archivos_CSV_con_etiquetas/20-11-2025_T344_T7_date_OK_etiquetado.csv'
data_filtrado.to_csv(salida, index=False)

print("Archivo guardado con éxito en:", salida)
print("Filas originales:", len(data))
print("Filas con etiqueta:", len(data_filtrado))
# Out:
# Archivo guardado con éxito en: Archivos_CSV_con_etiquetas/20-11-2025_T344_T7_date_OK_etiquetado.csv
# Filas originales: 4987371
# Filas con etiqueta: 79532

# %% [markdown]
# # T405

# %% [markdown]
# ### 20-11-2025_T405_T3_date_OK

# %%
import pandas as pd
ruta_archivo = 'Archivos_CSV_sin_etiquetas_dateOK/20-11-2025_T405_T3_date_OK.csv'
data = pd.read_csv(ruta_archivo)
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])
tiempo = data['dateTime_UTC']


# Definir los intervalos de tiempo y las actividades correspondientes
actividades = {
    (pd.Timestamp('2025-11-18 10:49:04.136'),pd.Timestamp('2025-11-18 10:50:27.499')): 'Caminando', 
    (pd.Timestamp('2025-11-18 11:03:20.154'),pd.Timestamp('2025-11-18 11:05:11.060')): 'Caminando', 
    (pd.Timestamp('2025-11-18 11:18:01.775'),pd.Timestamp('2025-11-18 11:19:39.911')): 'Caminando',
    (pd.Timestamp('2025-11-18 11:19:39.980'),pd.Timestamp('2025-11-18 11:19:48.020')): 'Comiendo',
    (pd.Timestamp('2025-11-18 11:19:48.089'),pd.Timestamp('2025-11-18 11:31:55.374')): 'Caminando',
    (pd.Timestamp('2025-11-18 11:34:26.494'),pd.Timestamp('2025-11-18 11:45:06.502')): 'Quieta',
}

tiempo_actual=0

# Función para asignar actividad basada en los intervalos de tiempo
def asignar_actividad(row):
    
    tiempo_actual = row['dateTime_UTC']

    for intervalo, actividad in actividades.items():
        inicio, fin = intervalo
        if inicio <= tiempo_actual <= fin:
            return actividad  # Devolver la etiqueta de actividad
    return None

# Aplicar la función a cada fila para crear una nueva columna 'actividad'
data['Actividades'] = data.apply(asignar_actividad, axis=1)

# Eliminar filas sin etiqueta
data_filtrado = data.dropna(subset=['Actividades'])


# Guardar el archivo CSV modificado
data_filtrado.to_csv('Archivos_CSV_con_etiquetas/20-11-2025_T405_T3_date_OK_etiquetado.csv', index=False)

# %% [markdown]
# # T76

# %% [markdown]
# ### 20-11-2025_T79_T5_date_OK

# %%
import pandas as pd
ruta_archivo = 'Archivos_CSV_sin_etiquetas_dateOK/20-11-2025_T79_T5_dateOK.csv'
data = pd.read_csv(ruta_archivo)
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])
tiempo = data['dateTime_UTC']


# Definir los intervalos de tiempo y las actividades correspondientes
actividades = {
    (pd.Timestamp('2025-11-15 09:05:14.111'),pd.Timestamp('2025-11-15 09:08:00.001')): 'Comiendo', 
    (pd.Timestamp('2025-11-15 09:08:13.199'),pd.Timestamp('2025-11-15 09:08:58.551')): 'Caminando',   
    (pd.Timestamp('2025-11-15 09:08:59.815'),pd.Timestamp('2025-11-15 09:09:27.042')): 'Comiendo',
    (pd.Timestamp('2025-11-15 09:09:27.112'),pd.Timestamp('2025-11-15 09:09:50.003')): 'Caminando',
    (pd.Timestamp('2025-11-15 09:09:50.074'),pd.Timestamp('2025-11-15 09:10:04.889')): 'Comiendo',
    (pd.Timestamp('2025-11-15 09:10:04.960'),pd.Timestamp('2025-11-15 09:19:04.069')): 'Caminando',
    (pd.Timestamp('2025-11-15 09:19:04.139'),pd.Timestamp('2025-11-15 09:19:28.007')): 'Comiendo',
    (pd.Timestamp('2025-11-15 09:10:04.960'),pd.Timestamp('2025-11-15 09:21:16.813')): 'Caminando',
    (pd.Timestamp('2025-11-15 09:21:16.883'),pd.Timestamp('2025-11-15 09:22:32.555')): 'Comiendo', 
    (pd.Timestamp('2025-11-15 09:22:32.625'),pd.Timestamp('2025-11-15 09:22:41.120')): 'Quieta',
    (pd.Timestamp('2025-11-15 09:22:41.190'),pd.Timestamp('2025-11-15 09:23:13.199')): 'Caminando',
    (pd.Timestamp('2025-11-15 09:23:13.269'),pd.Timestamp('2025-11-15 09:24:03.742')): 'Quieta', 
    (pd.Timestamp('2025-11-15 09:24:03.812'),pd.Timestamp('2025-11-15 09:26:11.002')): 'Caminando', 
    (pd.Timestamp('2025-11-15 09:31:33.005'),pd.Timestamp('2025-11-15 09:32:04.032')): 'Quieta', 
    (pd.Timestamp('2025-11-15 09:32:04.102'),pd.Timestamp('2025-11-15 09:33:36.623')): 'Caminando', 
    (pd.Timestamp('2025-11-15 09:33:36.693'),pd.Timestamp('2025-11-15 09:33:43.013')): 'Quieta', 
    (pd.Timestamp('2025-11-15 09:33:43.084'),pd.Timestamp('2025-11-15 09:35:36.519')): 'Caminando', 
    (pd.Timestamp('2025-11-15 09:35:36.589'),pd.Timestamp('2025-11-15 09:36:38.293')): 'Comiendo',
    (pd.Timestamp('2025-11-15 09:36:38.363'),pd.Timestamp('2025-11-15 09:36:46.506')): 'Caminando', 
    (pd.Timestamp('2025-11-15 09:36:46.576'),pd.Timestamp('2025-11-15 09:43:05.221')): 'Comiendo', 
    (pd.Timestamp('2025-11-15 09:43:39.478'),pd.Timestamp('2025-11-15 09:43:58.501')): 'Caminando', 
    (pd.Timestamp('2025-11-15 09:43:58.572'),pd.Timestamp('2025-11-15 09:44:38.232')): 'Comiendo', 
    (pd.Timestamp('2025-11-15 09:45:22.387'),pd.Timestamp('2025-11-15 09:46:35.111')): 'Comiendo', 
    (pd.Timestamp('2025-11-15 09:46:59.469'),pd.Timestamp('2025-11-15 09:47:28.257')): 'Caminando', 
    (pd.Timestamp('2025-11-15 09:47:28.327'),pd.Timestamp('2025-11-15 09:48:50.100')): 'Comiendo',
    (pd.Timestamp('2025-11-15 09:48:50.1701'),pd.Timestamp('2025-11-15 09:50:14.408')): 'Caminando', 
    (pd.Timestamp('2025-11-15 09:50:14.478'),pd.Timestamp('2025-11-15 09:51:34.643')): 'Comiendo',
    (pd.Timestamp('2025-11-15 09:51:34.714'),pd.Timestamp('2025-11-15 09:51:54.758')): 'Caminando',
    (pd.Timestamp('2025-11-15 09:53:29.556'),pd.Timestamp('2025-11-15 09:54:35.824')): 'Caminando',
    (pd.Timestamp('2025-11-15 09:54:35.894'),pd.Timestamp('2025-11-15 09:54:59.059')): 'Comiendo',
    (pd.Timestamp('2025-11-15 09:54:59.129'),pd.Timestamp('2025-11-15 10:04:32.647')): 'Caminando'
}

tiempo_actual=0

# Función para asignar actividad basada en los intervalos de tiempo
def asignar_actividad(row):
    
    tiempo_actual = row['dateTime_UTC']

    for intervalo, actividad in actividades.items():
        inicio, fin = intervalo
        if inicio <= tiempo_actual <= fin:
            return actividad  # Devolver la etiqueta de actividad
    return None

# Aplicar la función a cada fila para crear una nueva columna 'actividad'
data['Actividades'] = data.apply(asignar_actividad, axis=1)

# Eliminar filas sin etiqueta
data_filtrado = data.dropna(subset=['Actividades'])


# Guardar el archivo CSV modificado
data_filtrado.to_csv('Archivos_CSV_con_etiquetas/20-11-2025_T79_T5_dateOK_etiquetado.csv', index=False)

# %% [markdown]
# ## T337

# %% [markdown]
# ### 20-11-2025_T337_T6_date_OK

# %%
import pandas as pd
ruta_archivo = 'Archivos_CSV_sin_etiquetas_dateOK/20-11-2025_T337_T6_date_OK.csv'
data = pd.read_csv(ruta_archivo)
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])
tiempo = data['dateTime_UTC']


# Definir los intervalos de tiempo y las actividades correspondientes
actividades = {
    (pd.Timestamp('2025-11-16 12:39:38.892'),pd.Timestamp('2025-11-16 12:40:44.573')): 'Quieta', 
    (pd.Timestamp('2025-11-16 12:41:19.355'),pd.Timestamp('2025-11-16 12:43:03.092')): 'Caminando',    
    (pd.Timestamp('2025-11-16 12:43:29.741'),pd.Timestamp('2025-11-16 12:47:37.113')): 'Caminando',
    (pd.Timestamp('2025-11-16 12:47:59.955'),pd.Timestamp('2025-11-16 12:48:09.188')): 'Comiendo',
    (pd.Timestamp('2025-11-16 12:48:09.258'),pd.Timestamp('2025-11-16 12:50:09.028')): 'Caminando',
    (pd.Timestamp('2025-11-16 12:50:09.098'),pd.Timestamp('2025-11-16 13:41:11.846')): 'Quieta',
    (pd.Timestamp('2025-11-19 11:06:32.253'),pd.Timestamp('2025-11-19 11:08:00.355')): 'Caminando', 
    (pd.Timestamp('2025-11-19 13:49:08.634'),pd.Timestamp('2025-11-19 13:53:54.118')): 'Caminando',   
    (pd.Timestamp('2025-11-19 13:53:54.188'),pd.Timestamp('2025-11-19 13:56:41.857')): 'Quieta',
    (pd.Timestamp('2025-11-19 13:56:41.926'),pd.Timestamp('2025-11-19 14:01:01.796')): 'Caminando',
    (pd.Timestamp('2025-11-20 10:02:04.109'),pd.Timestamp('2024-02-14 12:20:41.419')): 'Copula',
    (pd.Timestamp('2025-11-20 10:03:11.312'),pd.Timestamp('2025-11-20 10:06:44.854')): 'Copula',
    (pd.Timestamp('2025-11-20 10:10:18.505'),pd.Timestamp('2025-11-20 10:10:22.253')): 'Copula', 
    (pd.Timestamp('2025-11-20 10:10:27.807'),pd.Timestamp('2025-11-20 10:10:31.556')): 'Copula'
}

tiempo_actual=0

# Función para asignar actividad basada en los intervalos de tiempo
def asignar_actividad(row):
    
    tiempo_actual = row['dateTime_UTC']

    for intervalo, actividad in actividades.items():
        inicio, fin = intervalo
        if inicio <= tiempo_actual <= fin:
            return actividad  # Devolver la etiqueta de actividad
    return None

# Aplicar la función a cada fila para crear una nueva columna 'actividad'
data['Actividades'] = data.apply(asignar_actividad, axis=1)

# Eliminar filas sin etiqueta
data_filtrado = data.dropna(subset=['Actividades'])


# Guardar el archivo CSV modificado
data_filtrado.to_csv('Archivos_CSV_con_etiquetas/20-11-2025_T337_T6_date_OK_etiquetado.csv', index=False)

# %% [markdown]
# ### 22-02-24_T337_T5_dateOK

# %%
import pandas as pd
ruta_archivo = 'Archivos_CSV_sin_etiquetas_dateOK/22-02-24_T337-T5_dateOK.csv'
data = pd.read_csv(ruta_archivo)
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])
tiempo = data['dateTime_UTC']


# Definir los intervalos de tiempo y las actividades correspondientes
actividades = {
    (pd.Timestamp('2024-02-14 12:11:02.431'),pd.Timestamp('2024-02-14 12:12:02.730')): 'Caminando', 
    (pd.Timestamp('2024-02-14 12:12:02.800'),pd.Timestamp('2024-02-14 12:13:08.013')): 'Quieta',    
    (pd.Timestamp('2024-02-14 12:13:08.084'),pd.Timestamp('2024-02-14 12:16:41.561')): 'Caminando',
    (pd.Timestamp('2024-02-14 12:16:46.615'),pd.Timestamp('2024-02-14 12:17:26.906')): 'Quieta',
    (pd.Timestamp('2024-02-14 12:17:36.456'),pd.Timestamp('2024-02-14 12:20:41.419')): 'Caminando',
    (pd.Timestamp('2024-02-14 12:24:35.526'),pd.Timestamp('2024-02-14 12:26:43.427')): 'Quieta'
}

tiempo_actual=0

# Función para asignar actividad basada en los intervalos de tiempo
def asignar_actividad(row):
    
    tiempo_actual = row['dateTime_UTC']

    for intervalo, actividad in actividades.items():
        inicio, fin = intervalo
        if inicio <= tiempo_actual <= fin:
            return actividad  # Devolver la etiqueta de actividad
    return None

# Aplicar la función a cada fila para crear una nueva columna 'actividad'
data['Actividades'] = data.apply(asignar_actividad, axis=1)


# Guardar el archivo CSV modificado
data.to_csv('Archivos_CSV_con_etiquetas/22-02-24_T337-T5_dateOK_etiquetado.csv', index=False)

# %% [markdown]
# ### 04-02-24_T337_T5_dateOK

# %%
import pandas as pd
ruta_archivo = 'Archivos_CSV_sin_etiquetas_dateOK/04-02-24_T337_T5_dateOK.csv'
data = pd.read_csv(ruta_archivo)
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])
tiempo = data['dateTime_UTC']


# Definir los intervalos de tiempo y las actividades correspondientes
actividades = {
    (pd.Timestamp('2024-02-02 09:18:34.054'),pd.Timestamp('2024-02-02 09:25:23.167')): 'Quieta', 
    (pd.Timestamp('2024-02-02 09:25:23.237'),pd.Timestamp('2024-02-02 09:25:34.753')): 'Caminando',    
    (pd.Timestamp('2024-02-02 09:25:40.441'),pd.Timestamp('2024-02-02 09:36:57.772')): 'Quieta',
    (pd.Timestamp('2024-02-02 09:38:26.145'),pd.Timestamp('2024-02-02 09:38:50.370')): 'Caminando',
    (pd.Timestamp('2024-02-02 09:38:50.370'),pd.Timestamp('2024-02-02 09:42:17.872')): 'Quieta',
    (pd.Timestamp('2024-02-02 09:42:17.942'),pd.Timestamp('2024-02-02 09:49:55.556')): 'Caminando',
    (pd.Timestamp('2024-02-02 09:50:10.301'),pd.Timestamp('2024-02-02 09:51:08.705')): 'Comiendo'
}

tiempo_actual=0

# Función para asignar actividad basada en los intervalos de tiempo
def asignar_actividad(row):
    
    tiempo_actual = row['dateTime_UTC']

    for intervalo, actividad in actividades.items():
        inicio, fin = intervalo
        if inicio <= tiempo_actual <= fin:
            return actividad  # Devolver la etiqueta de actividad
    return None

# Aplicar la función a cada fila para crear una nueva columna 'actividad'
data['Actividades'] = data.apply(asignar_actividad, axis=1)


# Guardar el archivo CSV modificado
data.to_csv('Archivos_CSV_con_etiquetas/04-02-24_T337_T5_dateOK_etiquetado.csv', index=False)

# %% [markdown]
# # Etiqueto los movimientos

# %% [markdown]
# ### Medicion tortuga aria

# %% [markdown]
# ## Movimientos
#
# ### Quieta: La tortuga no evidencia movimientos o está durmiendo
# ### Camina: La tortuga camina claramente
# ### Come: La tortuga está comiendo
# ### Escarba: La tortuga se mueve, no presenta claros desplazamientos, mueve las patas traseras sobre la tierra o piso, puede tener un objeto que la impida moverse delante

# %%
import pandas as pd
ruta_archivo = 'Archivos_CSV_sin_etiquetas_dateOK/22-02-25_Aria_T3_dateOk.csv'
data = pd.read_csv(ruta_archivo)
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])
tiempo = data['dateTime_UTC']


# Definir los intervalos de tiempo y las actividades correspondientes
actividades = {
    (pd.Timestamp('2025-02-17 16:01:25.618'),pd.Timestamp('2025-02-18 11:23:42.340')): 'Caminando', 
    (pd.Timestamp('2025-02-18 11:23:42.409'),pd.Timestamp('2025-02-18 12:36:53.927')): 'Quieta',    
    (pd.Timestamp('2025-02-18 12:36:53.996'),pd.Timestamp('2025-02-18 13:41:20.186')): 'Caminando',
    (pd.Timestamp('2025-02-18 14:05:37.436'),pd.Timestamp('2025-02-18 14:11:19.328')): 'Comiendo'
}

tiempo_actual=0

# Función para asignar actividad basada en los intervalos de tiempo
def asignar_actividad(row):
    
    tiempo_actual = row['dateTime_UTC']

    for intervalo, actividad in actividades.items():
        inicio, fin = intervalo
        if inicio <= tiempo_actual <= fin:
            return actividad  # Devolver la etiqueta de actividad
    return None

# Aplicar la función a cada fila para crear una nueva columna 'actividad'
data['Actividades'] = data.apply(asignar_actividad, axis=1)


# Guardar el archivo CSV modificado
data.to_csv('Archivos_CSV_con_etiquetas/22-02-25_Aria_T3_dateOk_etiquetado.csv', index=False)

# %% [markdown]
# ### Ingrid

# %%
import pandas as pd
ruta_archivo = 'Archivos_CSV_sin_etiquetas_dateOK/13-03-25_Ingrid_T5_dateOK.csv'
data = pd.read_csv(ruta_archivo)
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])
tiempo = data['dateTime_UTC']


# Definir los intervalos de tiempo y las actividades correspondientes
actividades = {
    (pd.Timestamp('2025-02-26 10:24:34.111'),pd.Timestamp('2025-02-26 10:35:48.637')): 'Caminando', 
    (pd.Timestamp('2025-02-26 10:35:48.708'),pd.Timestamp('2025-02-26 10:50:34.808')): 'Quieta',    
    (pd.Timestamp('2025-02-26 12:22:08.806'),pd.Timestamp('2025-02-26 12:50:27.652')): 'Caminando',
    (pd.Timestamp('2025-02-26 16:33:24.255'),pd.Timestamp('2025-02-26 16:34:52.139')): 'Comiendo',
    (pd.Timestamp('2025-02-27 11:53:16.589'),pd.Timestamp('2025-02-27 12:24:04.787')): 'Quieta',
    (pd.Timestamp('2025-02-27 12:24:04.787'),pd.Timestamp('2025-02-27 14:38:31.341')): 'Caminando'
}

tiempo_actual=0

# Función para asignar actividad basada en los intervalos de tiempo
def asignar_actividad(row):
    
    tiempo_actual = row['dateTime_UTC']

    for intervalo, actividad in actividades.items():
        inicio, fin = intervalo
        if inicio <= tiempo_actual <= fin:
            return actividad  # Devolver la etiqueta de actividad
    return None

# Aplicar la función a cada fila para crear una nueva columna 'actividad'
data['Actividades'] = data.apply(asignar_actividad, axis=1)


# Guardar el archivo CSV modificado
data.to_csv('Archivos_CSV_con_etiquetas/13-03-25_Ingrid_T5_dateOK_etiquetado.csv', index=False)

# %% [markdown]
# ### Medición tortuga

# %%
ruta_archivo = 'Archivos_CSV_sin_etiquetas/Medicion_tortuga_accelGyro.csv'
data = pd.read_csv(ruta_archivo)
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])
tiempo = data['dateTime_UTC']

# Definir los intervalos de tiempo y las actividades correspondientes
actividades = {
    (pd.Timestamp('1999-01-15 09:34:48.796200'),pd.Timestamp('1999-01-15 09:36:31.475400')): 'Caminando', 
    (pd.Timestamp('1999-01-15 09:36:31.544600'),pd.Timestamp('1999-01-15 09:36:42.133100')): 'Quieta',    
    (pd.Timestamp('1999-01-15 09:36:42.202200'),pd.Timestamp('1999-01-15 09:40:20.633000')): 'Caminando',
    (pd.Timestamp('1999-01-15 09:40:20.702100'),pd.Timestamp('1999-01-15 09:43:07.729300')): 'Quieta',
    (pd.Timestamp('1999-01-15 09:43:07.798500'),pd.Timestamp('1999-01-15 09:43:57.484200')): 'Caminando',
    (pd.Timestamp('1999-01-15 09:43:57.553300'),pd.Timestamp('1999-01-15 09:53:23.946500')): 'Quieta',
    (pd.Timestamp('1999-01-15 09:53:24.015700'),pd.Timestamp('1999-01-15 09:53:52.037300')): 'Caminando', #Esto en realidad no lo registré, pero parece un movimiento en la gráfica (lo que sí estoy seguro es que no estaba comiendo)
    (pd.Timestamp('1999-01-15 09:53:52.106500'),pd.Timestamp('1999-01-15 09:56:35.674300')): 'Quieta',
    (pd.Timestamp('1999-01-15 09:56:35.743400'),pd.Timestamp('1999-01-15 09:57:33.379600')): 'Caminando',
    (pd.Timestamp('1999-01-15 09:57:33.448800'),pd.Timestamp('1999-01-15 10:04:32.130600')): 'Quieta',
    (pd.Timestamp('1999-01-15 10:04:32.199800'),pd.Timestamp('1999-01-15 10:19:38.049000')): 'Comiendo',
    (pd.Timestamp('1999-01-15 10:19:38.118200'),pd.Timestamp('1999-01-15 10:20:09.391600')): 'Quieta',
    (pd.Timestamp('1999-01-15 10:20:09.460800'),pd.Timestamp('1999-01-15 10:20:54.714000')): 'Comiendo',
    (pd.Timestamp('1999-01-15 10:20:54.783200'),pd.Timestamp('1999-01-15 10:22:15.522800')): 'Quieta',
    (pd.Timestamp('1999-01-15 10:22:15.592000'),pd.Timestamp('1999-01-15 10:23:47.068900')): 'Comiendo',
    (pd.Timestamp('1999-01-15 10:23:47.138100'),pd.Timestamp('1999-01-15 10:24:15.362200')): 'Quieta',
    (pd.Timestamp('1999-01-15 10:24:15.431300'),pd.Timestamp('1999-01-15 10:26:16.099500')): 'Comiendo',
    (pd.Timestamp('1999-01-15 10:26:16.168700'),pd.Timestamp('1999-01-15 10:28:26.317800')): 'Quieta',
    (pd.Timestamp('1999-01-15 10:28:26.387000'),pd.Timestamp('1999-01-15 10:29:16.688400')): 'Caminando',
    (pd.Timestamp('1999-01-15 10:29:16.757600'),pd.Timestamp('1999-01-15 10:31:11.761800')): 'Quieta'
}

tiempo_actual=0

# Función para asignar actividad basada en los intervalos de tiempo
def asignar_actividad(row):
    
    tiempo_actual = row['dateTime_UTC']

    for intervalo, actividad in actividades.items():
        inicio, fin = intervalo
        if inicio <= tiempo_actual <= fin:
            return actividad  # Devolver la etiqueta de actividad
    return None

# Aplicar la función a cada fila para crear una nueva columna 'actividad'
data['Actividades'] = data.apply(asignar_actividad, axis=1)

# Guardar el archivo CSV modificado
data.to_csv('Archivos_con_etiquetas/Medicion_tortuga_accelGyro_etiquetado.csv', index=False)

# %%
import pandas as pd

# Leer el archivo CSV original
df = pd.read_csv('Archivos_con_etiquetas/Medicion_tortuga_accelGyro_etiquetado.csv')

# Convertir la columna de tiempo a un formato datetime
df['dateTime_UTC'] = pd.to_datetime(df['dateTime_UTC'])

# Definir los intervalos de tiempo para train y test
intervalos_train = [
    (pd.Timestamp('1999-01-15 09:34:48.796200'),pd.Timestamp('1999-01-15 09:35:40.132000')),
    (pd.Timestamp('1999-01-15 09:36:31.544600'),pd.Timestamp('1999-01-15 09:36:36.804600')),
    (pd.Timestamp('1999-01-15 09:36:42.202200'),pd.Timestamp('1999-01-15 09:38:31.383700')),
    (pd.Timestamp('1999-01-15 09:40:20.702100'),pd.Timestamp('1999-01-15 09:41:44.215900')),
    (pd.Timestamp('1999-01-15 09:43:07.798500'),pd.Timestamp('1999-01-15 09:43:32.641000')),
    (pd.Timestamp('1999-01-15 09:43:57.553300'),pd.Timestamp('1999-01-15 09:48:15.910500')),
    (pd.Timestamp('1999-01-15 09:53:24.015700'),pd.Timestamp('1999-01-15 09:53:37.992900')),
    (pd.Timestamp('1999-01-15 09:53:52.106500'),pd.Timestamp('1999-01-15 09:55:13.897400')),
    (pd.Timestamp('1999-01-15 09:56:35.743400'),pd.Timestamp('1999-01-15 09:57:04.529500')),
    (pd.Timestamp('1999-01-15 09:57:33.448800'),pd.Timestamp('1999-01-15 10:01:02.758200')),
    (pd.Timestamp('1999-01-15 10:04:32.199800'),pd.Timestamp('1999-01-15 10:12:05.741700')),
    (pd.Timestamp('1999-01-15 10:19:38.118200'),pd.Timestamp('1999-01-15 10:19:53.749200')),
    (pd.Timestamp('1999-01-15 10:20:09.460800'),pd.Timestamp('1999-01-15 10:20:32.082000')),
    (pd.Timestamp('1999-01-15 10:20:54.783200'),pd.Timestamp('1999-01-15 10:21:35.121900')),
    (pd.Timestamp('1999-01-15 10:22:15.592000'),pd.Timestamp('1999-01-15 10:23:01.327600')),
    (pd.Timestamp('1999-01-15 10:23:47.138100'),pd.Timestamp('1999-01-15 10:24:01.253100')),
    (pd.Timestamp('1999-01-15 10:24:15.431300'),pd.Timestamp('1999-01-15 10:25:15.765300')),
    (pd.Timestamp('1999-01-15 10:26:16.168700'),pd.Timestamp('1999-01-15 10:27:21.209100')),
    (pd.Timestamp('1999-01-15 10:28:26.387000'),pd.Timestamp('1999-01-15 10:28:51.503100')),
    (pd.Timestamp('1999-01-15 10:29:16.757600'),pd.Timestamp('1999-01-15 10:30:14.262600'))
    
]

intervalos_test = [
    (pd.Timestamp('1999-01-15 09:35:40.201200'),pd.Timestamp('1999-01-15 09:36:31.475400')),
    (pd.Timestamp('1999-01-15 09:36:36.873800'),pd.Timestamp('1999-01-15 09:36:42.133100')),
    (pd.Timestamp('1999-01-15 09:38:31.452900'),pd.Timestamp('1999-01-15 09:40:20.633000')),
    (pd.Timestamp('1999-01-15 09:41:44.285100'),pd.Timestamp('1999-01-15 09:43:07.729300')),
    (pd.Timestamp('1999-01-15 09:43:32.710200'),pd.Timestamp('1999-01-15 09:43:57.484200')),
    (pd.Timestamp('1999-01-15 09:48:15.979700'),pd.Timestamp('1999-01-15 09:53:23.946500')),
    (pd.Timestamp('1999-01-15 09:53:38.062100'),pd.Timestamp('1999-01-15 09:53:52.037300')),
    (pd.Timestamp('1999-01-15 09:55:13.966500'),pd.Timestamp('1999-01-15 09:56:35.674300')),
    (pd.Timestamp('1999-01-15 09:57:04.598700'),pd.Timestamp('1999-01-15 09:57:33.379600')),
    (pd.Timestamp('1999-01-15 10:01:02.827400'),pd.Timestamp('1999-01-15 10:04:32.130600')),
    (pd.Timestamp('1999-01-15 10:12:05.810900'),pd.Timestamp('1999-01-15 10:19:38.049000')),
    (pd.Timestamp('1999-01-15 10:19:53.819400'),pd.Timestamp('1999-01-15 10:20:09.391600')),
    (pd.Timestamp('1999-01-15 10:20:32.151100'),pd.Timestamp('1999-01-15 10:20:54.714000')),
    (pd.Timestamp('1999-01-15 10:21:35.192400'),pd.Timestamp('1999-01-15 10:22:15.522800')),
    (pd.Timestamp('1999-01-15 10:23:01.396800'),pd.Timestamp('1999-01-15 10:23:47.068900')),
    (pd.Timestamp('1999-01-15 10:24:01.322300'),pd.Timestamp('1999-01-15 10:24:15.362200')),
    (pd.Timestamp('1999-01-15 10:25:15.834500'),pd.Timestamp('1999-01-15 10:26:16.099500')),
    (pd.Timestamp('1999-01-15 10:27:21.278300'),pd.Timestamp('1999-01-15 10:28:26.317800')),
    (pd.Timestamp('1999-01-15 10:28:51.572300'),pd.Timestamp('1999-01-15 10:29:16.688400')),
    (pd.Timestamp('1999-01-15 10:30:14.331800'),pd.Timestamp('1999-01-15 10:31:11.761800'))
]

# Filtrar las filas según los intervalos de train
train_df = pd.concat([
    df[(df['dateTime_UTC'] >= pd.to_datetime(inicio)) & (df['dateTime_UTC'] <= pd.to_datetime(fin))]
    for inicio, fin in intervalos_train
])

# Filtrar las filas según los intervalos de test
test_df = pd.concat([
    df[(df['dateTime_UTC'] >= pd.to_datetime(inicio)) & (df['dateTime_UTC'] <= pd.to_datetime(fin))]
    for inicio, fin in intervalos_test
])

# Guardar los nuevos archivos CSV
train_df.to_csv('Archivos_con_etiquetas/train_tortuga.csv', index=False)
test_df.to_csv('Archivos_con_etiquetas/test_tortuga.csv', index=False)

# %% [markdown]
# ### Medición manual train

# %%
data = pd.read_csv('Archivos_CSV_sin_etiquetas/Medicion_manual_train_accelGyro.csv')
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])
# Definir los intervalos de tiempo y las actividades correspondientes
actividades = {
    (pd.Timestamp('1999-01-02 04:00:02.4324'),pd.Timestamp('1999-01-02 04:00:13.0574')): 'Quieto', 
    (pd.Timestamp('1999-01-02 04:00:13.1264'),pd.Timestamp('1999-01-02 04:01:40.4941')): 'Movimiento_1',    
    (pd.Timestamp('1999-01-02 04:01:40.5633'),pd.Timestamp('1999-01-02 04:01:50.3875')): 'Quieto',
    (pd.Timestamp('1999-01-02 04:01:50.4567'),pd.Timestamp('1999-01-02 04:02:48.5069')): 'Movimiento_2',
    (pd.Timestamp('1999-01-02 04:02:48.5761'),pd.Timestamp('1999-01-02 04:03:09.5365')): 'Quieto',
    (pd.Timestamp('1999-01-02 04:03:09.6057'),pd.Timestamp('1999-01-02 04:04:23.8471')): 'Movimiento_3',
    (pd.Timestamp('1999-01-02 04:04:23.9163'),pd.Timestamp('1999-01-02 04:04:38.5851')): 'Quieto', 
    (pd.Timestamp('1999-01-02 04:04:38.6543'),pd.Timestamp('1999-01-02 04:06:02.9294')): 'Movimiento_4',
    (pd.Timestamp('1999-01-02 04:06:02.9986'),pd.Timestamp('1999-01-02 04:06:07.2882')): 'Quieto',
    
}
tiempo_actual=0

# Función para asignar actividad basada en los intervalos de tiempo
def asignar_actividad(row):
    
    tiempo_actual = row['dateTime_UTC']

    for intervalo, actividad in actividades.items():
        inicio, fin = intervalo
        if inicio <= tiempo_actual <= fin:
            return actividad  # Devolver la etiqueta de actividad
    return None

# Aplicar la función a cada fila para crear una nueva columna 'actividad'
data['Actividades'] = data.apply(asignar_actividad, axis=1)

# Guardar el archivo CSV modificado
data.to_csv('Archivos_con_etiquetas/Medicion_manual_train_accelGyro_etiquetado.csv', index=False)

# %% [markdown]
# ### Medición manual test

# %%
data = pd.read_csv('Archivos_CSV_sin_etiquetas/Medicion_manual_test_accelGyro.csv')
data['dateTime_UTC'] = pd.to_datetime(data['dateTime_UTC'])

# Definir los intervalos de tiempo y las actividades correspondientes
actividades = {
    (pd.Timestamp('1999-01-02 04:00:02.4334'),pd.Timestamp('1999-01-02 04:00:11.8163')): 'Quieto', 
    (pd.Timestamp('1999-01-02 04:00:11.8853'),pd.Timestamp('1999-01-02 04:01:38.7758')): 'Movimiento_3',    
    (pd.Timestamp('1999-01-02 04:01:38.8447'),pd.Timestamp('1999-01-02 04:01:55.0877')): 'Quieto',
    (pd.Timestamp('1999-01-02 04:01:55.1569'),pd.Timestamp('1999-01-02 04:03:37.5635')): 'Movimiento_1',
    (pd.Timestamp('1999-01-02 04:03:37.6327'),pd.Timestamp('1999-01-02 04:04:09.1814')): 'Quieto',
    (pd.Timestamp('1999-01-02 04:04:09.2506'),pd.Timestamp('1999-01-02 04:05:52.4831')): 'Movimiento_2',
    (pd.Timestamp('1999-01-02 04:05:52.5523'),pd.Timestamp('1999-01-02 04:06:44.7219')): 'Quieto', 
    (pd.Timestamp('1999-01-02 04:06:44.7911'),pd.Timestamp('1999-01-02 04:08:04.2935')): 'Movimiento_4',
    (pd.Timestamp('1999-01-02 04:08:04.3627'),pd.Timestamp('1999-01-02 04:08:08.9297')): 'Quieto',
    
}
tiempo_actual=0

# Función para asignar actividad basada en los intervalos de tiempo
def asignar_actividad(row):
    
    tiempo_actual = row['dateTime_UTC']

    for intervalo, actividad in actividades.items():
        inicio, fin = intervalo
        if inicio <= tiempo_actual <= fin:
            return actividad  # Devolver la etiqueta de actividad
    return None

# Aplicar la función a cada fila para crear una nueva columna 'actividad'
data['Actividades'] = data.apply(asignar_actividad, axis=1)

# Guardar el archivo CSV modificado
data.to_csv('Archivos_con_etiquetas/Medicion_manual_test_accelGyro_etiquetado.csv', index=False)
