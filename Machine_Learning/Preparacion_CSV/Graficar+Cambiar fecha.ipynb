# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib qt
# Leer el archivo CSV en un DataFrame
df = pd.read_csv('Archivos_CSV_sin_etiquetas_dateOK/20-11-2025_T79_T5_dateOK.csv')

# Convertir la columna dateTime_UTC a tipo datetime
df['dateTime_UTC'] = pd.to_datetime(df['dateTime_UTC'])

# # Ajustar la fecha y hora a la real (sumando cantidad de segundos)
# df['dateTime_UTC'] = df['dateTime_UTC'] + pd.Timedelta(seconds=847946758)
# df.to_csv('Archivos_CSV_sin_etiquetas_dateOK/20-11-2025_T79_T5_dateOK.csv', index=False)
#Graficar las aceleraciones en función del tiempo
plt.figure(figsize=(15, 7))
plt.plot(df['dateTime_UTC'], df['ax'], label='ax')
# plt.plot(df['dateTime_UTC'], df['ay'], label='ay')
# plt.plot(df['dateTime_UTC'], df['az'], label='az')
plt.xlabel('Tiempo')
plt.ylabel('Aceleración')
plt.title('Aceleraciones en función del tiempo')
plt.legend()
plt.show()
